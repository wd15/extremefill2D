# %%
# %load_ext autoreload
# %autoreload 2

import pylab

from matplotlib.patches import FancyArrowPatch
from extremefill.simulation import Simulation
from schematicViewer import SchematicViewer

# from matplotlib import rc
# matplotlib.use('Agg')
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# rc('text', usetex=True)
# pylab.ioff()
# pylab.hold(True)

            
SchematicViewer().plot('fig2.png')
