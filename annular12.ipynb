# %%
from tools import batch_launch

kPluses = np.logspace(0, 4, 20)
kMinuses = np.logspace(6, 9, 20)

# !date
rboundary = 50e-6 / np.sqrt(np.pi)
    
reason = "Running simulation for k+ v k- with Nx=100"
    
for kPlus in kPluses:
    for kMinus in kMinuses:
        batch_launch(reason=reason,
                     tags=['annular56'],
                     kPlus=kPlus,
                     kMinus=kMinus,
                     rboundary=50e-6 / np.sqrt(np.pi),
                     Nx=100,
                     spacing_ratio=1.2,
                     CFL=0.1,
                     levelset_update_ncell=5,
                     data_frequency=100,
                     bulkSuppressor=0.06,
                     appliedPotential=-0.45)
# Out:
# Wed Sep 25 18:09:01 EDT 2013

# %%
# %load_ext autoreload
# %autoreload 2
from tools import getSMTRecords, smt_ipy_table
records = getSMTRecords(tags=['annular56'])
# Out:
# Created Django record store using PostgreSQL

# %%
annular56Records = records

# %%
from multiViewer import MultiViewer
from tools import getRecord

kPluses = np.logspace(0, 4, 20)
kMinuses = np.logspace(6, 9, 20)

reorderedRecords = [[getRecord(records=annular56Records, kPlus=kPlus, kMinus=kMinus) for kPlus in kPluses] for kMinus in kMinuses]

viewer = MultiViewer(reorderedRecords,
                     rowtitle=lambda r: r'$k^-$={0}'.format(r.parameters['kMinus']),
                     columntitle=lambda r: r'$k^+$={0}'.format(r.parameters['kPlus']),
                     figsize=(1.5, 6))

viewer.plot(times=np.arange(20) * 5000. / 19.)

smt_ipy_table([j for i in reorderedRecords for j in i if j],
               fields=['label', 'timestamp', 'parameters', 'duration', 'version', 'tags'],
               parameters=['kPlus', 'kMinus', 'bulkSuppressor', 'appliedPotential'])
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Label</b></td><td  style="background-color:LightGray;"><b>Timestamp</b></td><td  style="background-color:LightGray;"><b>Parameters</b></td><td  style="background-color:LightGray;"><b>Duration</b></td><td  style="background-color:LightGray;"><b>Version</b></td><td  style="background-color:LightGray;"><b>Tags</b></td></tr><tr><td  style="background-color:Ivory;"><code>759a81aa7744</code></td><td  style="background-color:Ivory;">2013-09-25 18:09</td><td  style="background-color:Ivory;"><code>kPlus: 1.0, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:Ivory;">1h 28m 12.15s</td><td  style="background-color:Ivory;"><code>43fd70c2edaa</code></td><td  style="background-color:Ivory;">annular56</td></tr><tr><td  style="background-color:AliceBlue;"><code>ec10a148d7ce</code></td><td  style="background-color:AliceBlue;">2013-09-25 18:09</td><td  style="background-color:AliceBlue;"><code>kPlus: 1.62377673919, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:AliceBlue;">1h 29m 42.45s</td><td  style="background-color:AliceBlue;"><code>43fd70c2edaa</code></td><td  style="background-color:AliceBlue;">annular56</td></tr><tr><td  style="background-color:Ivory;"><code>c7741645b362</code></td><td  style="background-color:Ivory;">2013-09-25 18:09</td><td  style="background-color:Ivory;"><code>kPlus: 2.63665089873, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:Ivory;">2h 6m 16.46s</td><td  style="background-color:Ivory;"><code>43fd70c2edaa</code></td><td  style="background-color:Ivory;">annular56</td></tr><tr><td  style="background-color:AliceBlue;"><code>089e5cd81745</code></td><td  style="background-color:AliceBlue;">2013-09-25 18:09</td><td  style="background-color:AliceBlue;"><code>kPlus: 4.28133239872, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:AliceBlue;">1h 37m 44.86s</td><td  style="background-color:AliceBlue;"><code>43fd70c2edaa</code></td><td  style="background-color:AliceBlue;">annular56</td></tr><tr><td  style="background-color:Ivory;"><code>eefff3b8db61</code></td><td  style="background-color:Ivory;">2013-09-25 18:09</td><td  style="background-color:Ivory;"><code>kPlus: 6.95192796178, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:Ivory;">2h 19m 47.59s</td><td  style="background-color:Ivory;"><code>43fd70c2edaa</code></td><td  style="background-color:Ivory;">annular56</td></tr><tr><td  style="background-color:AliceBlue;"><code>753790524211</code></td><td  style="background-color:AliceBlue;">2013-09-25 18:10</td><td  style="background-color:AliceBlue;"><code>kPlus: 11.2883789168, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:AliceBlue;">2h 59m 9.15s</td><td  style="background-color:AliceBlue;"><code>43fd70c2edaa</code></td><td  style="background-color:AliceBlue;">annular56</td></tr><tr><td  style="background-color:Ivory;"><code>91aadaabbbb9</code></td><td  style="background-color:Ivory;">2013-09-25 18:10</td><td  style="background-color:Ivory;"><code>kPlus: 18.3298071083, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:Ivory;">2h 35m 52.33s</td><td  style="background-color:Ivory;"><code>43fd70c2edaa</code></td><td  style="background-color:Ivory;">annular56</td></tr><tr><td  style="background-color:AliceBlue;"><code>f756c84e7382</code></td><td  style="background-color:AliceBlue;">2013-09-25 18:10</td><td  style="background-color:AliceBlue;"><code>kPlus: 29.7635144163, kMinus: 1000000.0, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:AliceBlue;">4m  ...

# %%
from multiViewer import MultiViewer
from tools import getRecord

kPluses = np.logspace(0, 4, 20)[13:14]
kMinuses = np.logspace(6, 9, 20)[10:11]

reorderedRecords = [[getRecord(records=annular56Records, kPlus=kPlus, kMinus=kMinus) for kPlus in kPluses] for kMinus in kMinuses]

viewer = MultiViewer(reorderedRecords,
                     rowtitle=lambda r: r'$k^-$={0}'.format(r.parameters['kMinus']),
                     columntitle=lambda r: r'$k^+$={0}'.format(r.parameters['kPlus']),
                     figsize=(1.5, 6))

viewer.plot(times=np.arange(20) * 5000. / 19., filename='fill.png')

smt_ipy_table([j for i in reorderedRecords for j in i if j],
               fields=['label', 'timestamp', 'parameters', 'duration', 'version', 'tags'],
               parameters=['kPlus', 'kMinus', 'bulkSuppressor', 'appliedPotential'])
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Label</b></td><td  style="background-color:LightGray;"><b>Timestamp</b></td><td  style="background-color:LightGray;"><b>Parameters</b></td><td  style="background-color:LightGray;"><b>Duration</b></td><td  style="background-color:LightGray;"><b>Version</b></td><td  style="background-color:LightGray;"><b>Tags</b></td></tr><tr><td  style="background-color:Ivory;"><code>9a491b5db789</code></td><td  style="background-color:Ivory;">2013-09-25 18:09</td><td  style="background-color:Ivory;"><code>kPlus: 545.559478117, kMinus: 37926901.9073, bulkSuppressor: 0.06, appliedPotential: -0.45</code></td><td  style="background-color:Ivory;">2h 34m 18.81s</td><td  style="background-color:Ivory;"><code>43fd70c2edaa</code></td><td  style="background-color:Ivory;">annular56</td></tr></table>
