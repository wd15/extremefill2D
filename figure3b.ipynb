# %% [markdown]
# ## Notebook for generation of Figure 3(b)

# %%
# %load_ext autoreload
# %autoreload 2
from tools import getSMTRecords, smt_ipy_table
records = getSMTRecords(tags=['annular56'])
# Out:
# Created Django record store using PostgreSQL

# %%
from multiViewer import MultiViewer
from tools import getRecord

kPluses = np.logspace(0, 4, 20)[[10, 12, 14, 16]][::-1]
kMinuses = np.logspace(6, 9, 20)[[9, 10, 14, 19]]

reorderedRecords = [[getRecord(records=records, kPlus=kPlus, kMinus=kMinus) for kMinus in kMinuses] for kPlus in kPluses]

def me(n):
    s = '%1.1e' % n
    m, e = s.split('e')
    return float(m), int(e)

def rowlabelold(r):
    m, e = me(r.parameters['kPlus'])
    label = '$k^+={0:1.1f}\\times 10^{{{1}}}$'.format(m, e)
    unit = '$\power{\meter}{3}\per\mole\cdot\second$'
    return '{0} ({1})'.format(label, unit)

def rowlabel(r):
    m, e = me(r.parameters['kPlus'])
    return '${0:1.1f}\\times 10^{{{1}}}$'.format(m, e)

def columnlabelold(r):
    m, e = me(r.parameters['kMinus'])
    label = '$k^-={0:1.1f}\\times 10^{{{1}}}$'.format(m, e)
    unit = '$1\per\metre$'
    return '{0} ({1})'.format(label, unit)

def columnlabel(r):
    m, e = me(r.parameters['kMinus'])
    return '${0:1.1f}\\times 10^{{{1}}}$'.format(m, e)

viewer = MultiViewer(reorderedRecords,
                     rowtitle=rowlabel,
                     columntitle=columnlabel,
                     figsize=(1.15, 5.))

viewer.plot(times=np.arange(40) * 5000. / 39, filename='figure3b.png')

smt_ipy_table([j for i in reorderedRecords for j in i if j],
              fields=['label', 'timestamp', 'parameters', 'duration', 'version', 'tags'],
              parameters=['kPlus', 'kMinus', 'appliedPotential', 'bulkSuppressor', 'Nx'])
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Label</b></td><td  style="background-color:LightGray;"><b>Timestamp</b></td><td  style="background-color:LightGray;"><b>Parameters</b></td><td  style="background-color:LightGray;"><b>Duration</b></td><td  style="background-color:LightGray;"><b>Version</b></td><td  style="background-color:LightGray;"><b>Tags</b></td></tr><tr><td  style="background-color:Ivory;"><code>865ce676</code></td><td  style="background-color:Ivory;">2013-09-25 18:21</td><td  style="background-color:Ivory;"><code>kPlus: 2335.72146909, kMinus: 26366508.9873, appliedPotential: -0.45, bulkSuppressor: 0.06, Nx: 100</code></td><td  style="background-color:Ivory;">6m 30.16s</td><td  style="background-color:Ivory;"><code>43fd70c2edaa</code></td><td  style="background-color:Ivory;">annular56</td></tr><tr><td  style="background-color:AliceBlue;"><code>0ba3a14b</code></td><td  style="background-color:AliceBlue;">2013-09-25 18:23</td><td  style="background-color:AliceBlue;"><code>kPlus: 2335.72146909, kMinus: 37926901.9073, appliedPotential: -0.