# %% [markdown]
# ## Comparing $k^+$
#
# The following two cells show the results for 1D steady and 2D extreme fill simulations. The 2D results mostly make sense in terms of the fill and fail boundaries when compared with the 1D.
# The main difference is that the $k^+=1000$ case shows a complete shutdown in 2D, but would have been  is a 1D fill. This isn't really surprising.
# Also for the $k^+=50$ case, the 2D result just failed whereas in the 1D case this would probably scrape in as a fill although I'm not entirely sure, but it is certainly an edge case.
#
# This was all simulated with Nx=300 so the next set of simulations will be with Nx=600 and Nx=1200. Hopefully, these results won't show any qualitative change in the fill/fail characteristics.

# %%
import matplotlib
import pylab
import extremefill
extremefill.generateFigures(datafile='/users/wd15/git/extremefill/data.h5', fignumbers=(3,), filesuffix=())
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(10, 8)
pylab.show()
# Out:
# **************
# varying kPlus
# ------------
# kPlus value: 0.01
# ------------
# kPlus value: 5.0
# ------------
# kPlus value: 25.0
# ------------
# kPlus value: 50.0
# ------------
# kPlus value: 100.0
# ------------
# kPlus value: 1000.0

# %%
from viewer import Records
from viewer import ContourViewer
records = Records().by_tag('serialnumber9')
for kPlus in (0.01, 5.0, 25.0, 50.0, 100.0, 1000.0):
    record = records.by_parameter('kPlus', kPlus)
    v = ContourViewer(record)
    v.plot()

# %%
from viewer import Records
from viewer import ContourViewer
records = Records().by_tag('serialnumber10').by_parameter('Nx', 600)
for kPlus in (0.01, 5.0, 25.0, 50.0, 100.0, 1000.0):
    record = records.by_parameter('kPlus', kPlus)
    v = ContourViewer(record)
    v.plot()

# %%
from viewer import Records
from viewer import ContourViewer
records = Records().by_tag('serialnumber10').by_parameter('Nx', 1200)
for kPlus in (0.01, 5.0, 25.0, 50.0, 100.0, 1000.0):
    record = records.by_parameter('kPlus', kPlus)
    v = ContourViewer(record)
    v.plot()

# %% [markdown]
# Simulation launched on `Wed Apr  3 16:11:28 EDT 2013` with `serialnumber10`
#
# <pre><code>
# 1676353 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide3@r001                         1
# 1676354 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide64@r037                        1
# 1676355 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide64@r037                        1
# 1676356 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide64@r037                        1
# 1676357 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# 1676358 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# 1676359 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r011                         1
# 1676360 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# 1676361 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# 1676362 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# 1676363 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# 1676364 0.03125 launcher   wd15         r     04/03/2013 15:50:50 wide2@r013                         1
# </code></pre>

# %% [markdown]
# ## Compare $k^-$
#
# The lower values for $k^-$ for which the deposition is highly segregated tends to shutdown more quickly.

# %%
import matplotlib
import pylab
import extremefill
extremefill.generateFigures(datafile='/users/wd15/git/extremefill/data.h5', fignumbers=(4,), filesuffix=())
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(10, 8)
pylab.show()
# Out:
# **************
# varying kMinus
# ------------
# kMinus value: 10000000.0
# ------------
# kMinus value: 15000000.0
# ------------
# kMinus value: 20000000.0
# ------------
# kMinus value: 25000000.0
# ------------
# kMinus value: 30000000.0

# %%
from viewer import Records
from viewer import ContourViewer
records = Records().by_tag('serialnumber11').by_parameter('Nx', 300)
for kMinus in (1e7, 1.5e7, 2e7, 2.5e7, 3e7):
    record = records.by_parameter('kMinus', kMinus)
    v = ContourViewer(record)
    v.plot()

# %%
from viewer import Records
from viewer import ContourViewer
records = Records().by_tag('serialnumber11').by_parameter('Nx', 600)
for kMinus in (1e7, 1.5e7, 2e7, 2.5e7, 3e7):
    record = records.by_parameter('kMinus', kMinus)
    v = ContourViewer(record)
    v.plot()

# %% [markdown]
# ## Compare $h$

# %%
import matplotlib
import pylab
import extremefill 
extremefill.generateFigures(datafile='/users/wd15/git/extremefill/data.h5', fignumbers=(6,), filesuffix=())
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(10, 8)
pylab.show()
# Out:
# **************
# varying featureDepth
# ------------
# featureDepth value: 8.5e-05
# ------------
# featureDepth value: 7.5e-05
# ------------
# featureDepth value: 6.5e-05
# ------------
# featureDepth value: 5.5e-05
# ------------
# featureDepth value: 4.5e-05
# ------------
# featureDepth value: 3.5e-05
# ------------
# featureDepth value: 2.5e-05
# ------------
# featureDepth value: 1.5e-05

# %%
from viewer import Records
from viewer import ContourViewer
records = Records().by_tag('serialnumber12').by_parameter('Nx', 300)
for featureDepth in (85e-6, 75e-6, 65e-6, 55e-6, 45e-6, 35e-6, 25e-6, 15e-6):
    record = records.by_parameter('featureDepth', featureDepth)
    v = ContourViewer(record)
    v.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-04f8f37b8b0c> in <module>()
#       4 for featureDepth in (85e-6, 75e-6, 65e-6, 55e-6, 45e-6, 35e-6, 30e-6, 25e-6, 15e-6):
#       5     record = records.by_parameter('featureDepth', featureDepth)
# ----> 6     v = ContourViewer(record)
#       7     v.plot()
#
# /users/wd15/git/extremefill-data/viewer.pyc in __init__(self, baseRecord, records, times, colors)
#     148             datafiles = records.datafiles
#     149
# --> 150         super(ContourViewer, self).__init__(basedatafile=baseRecord.datafiles[0],
#     151                                             datafiles=datafiles,
#     152                                             labels=None,
#
# IndexError: list index out of range

# %% [markdown]
# Simulation launched on `Thu Apr  4 16:34:36 EDT 2013` and tag of `serialnumber14`
#
# <pre><code>
# Your job 1676501 ("launcher") has been submitted
# Your job 1676502 ("launcher") has been submitted
# Your job 1676503 ("launcher") has been submitted
# Your job 1676504 ("launcher") has been submitted
# Your job 1676505 ("launcher") has been submitted
# Your job 1676506 ("launcher") has been submitted
# Your job 1676507 ("launcher") has been submitted
# Your job 1676508 ("launcher") has been submitted
# Your job 1676509 ("launcher") has been submitted
# Your job 1676510 ("launcher") has been submitted
# Your job 1676511 ("launcher") has been submitted
# Your job 1676512 ("launcher") has been submitted
# Your job 1676513 ("launcher") has been submitted
# Your job 1676514 ("launcher") has been submitted
# Your job 1676515 ("launcher") has been submitted
# Your job 1676516 ("launcher") has been submitted
# </code></pre>

# %% [markdown]
# ## Compare $\delta_{\text{REF}}$

# %% [markdown]
# Simulation launched on `Thu Apr  4 16:13:42 EDT 2013` and tag of `serialnumber13`
#
# <pre><code>
# Your job 1676484 ("launcher") has been submitted
# Your job 1676485 ("launcher") has been submitted
# Your job 1676486 ("launcher") has been submitted
# Your job 1676487 ("launcher") has been submitted
# Your job 1676488 ("launcher") has been submitted
# Your job 1676489 ("launcher") has been submitted
# Your job 1676490 ("launcher") has been submitted
# Your job 1676491 ("launcher") has been submitted
# Your job 1676492 ("launcher") has been submitted
# Your job 1676493 ("launcher") has been submitted
# Your job 1676494 ("launcher") has been submitted
# Your job 1676495 ("launcher") has been submitted
# </code></pre>
