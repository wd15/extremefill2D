# %%
# %load_ext autoreload
# %autoreload 2

import pylab

from extremefill2D.schematicViewer import SchematicViewer

# from matplotlib import rc
# matplotlib.use('Agg')
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# rc('text', usetex=True)
# pylab.ioff()
# pylab.hold(True)

            
SchematicViewer().plot('../extremefill2D/fig2.png')
